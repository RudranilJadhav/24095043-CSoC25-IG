# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error

# %%
train_set = pd.read_csv('train.csv')
test_set = pd.read_csv('test.csv')

x_train = np.array(train_set.drop(['median_house_value'], axis=1))
y_train = np.array(train_set['median_house_value'])

x_test = np.array(test_set.drop(['median_house_value'], axis=1))
y_test = np.array(test_set['median_house_value'])

# %%
model = LinearRegression()
model.fit(x_train,y_train)
y_hat = model.predict(x_test)

# %%
print("Coefficient (slope):", model.coef_)
print("Intercept:", model.intercept_)
print("Mean absolute error:", mean_absolute_error(y_test, y_hat))
print("Mean squared error:", mean_squared_error(y_test, y_hat))
print("R² score:", r2_score(y_test, y_hat))
# Out:
# Coefficient (slope): [-1.07153329e+09 -1.04403493e+09  3.93175803e+07  8.25591649e+04
#   1.63331253e+09 -7.66790149e+08 -2.16095330e+09  4.88553144e+09
#  -1.05698773e+09 -9.00800268e+08 -2.99652924e+08  1.18977530e+10]
# Intercept: -37499211.58380157
# Mean absolute error: 48529.88453830957
# Mean squared error: 4492851433.29812
# R² score: 0.6597315275251352

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_hat, alpha=0.07)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r', lw=1)
plt.xlabel("Actual Median House Value")
plt.ylabel("Predicted Median House Value")
plt.title("Actual vs Predicted House Values")
plt.show()
